# %%
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %matplotlib inline

# %%
SIZE = 200

# %%
def loadImage(path, cropsection, size):
    img_ = Image.open(path).convert('RGB').crop(cropsection).resize(size, Image.NEAREST) # Rezisemethode nicht ändern
    img = np.array(img_)
    img_.close()
    return img

# %%
background = loadImage("data/Oregon_Bitmap.bmp", (0,0,4000,4000),(200,200))

# %%
def drawImage(field, index):
    plt.imshow(background / 255 * np.expand_dims(1 - result[index,:,:,5], axis = 2))
    plt.show()

# %%
for i in range(5,7):
    result = np.load("result/Oregon"+str(i)+".npy")
    for j in range(50):
        plt.imshow(background / 255 * np.expand_dims(1 - result[j*2,:,:,5], axis = 2))
        plt.title("Oregon Fire: 1/r , radius = 1")
        plt.savefig("result/frames/frame"+str(j + i * 100))
        plt.show()
